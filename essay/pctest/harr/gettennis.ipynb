# %%
import cv2
import matplotlib.pyplot as plt

# %%
aaa = cv2.imread('tennis/t4.jpg')

# %%
plt.imshow(aaa, cmap=plt.cm.brg)

# %%
bbb = aaa[350:470, 535:655]

# %%
plt.imshow(bbb, cmap=plt.cm.brg)

# %%
cv2.imwrite('tnn/a4.jpg', bbb)
# Out:
# True

# %%
bbb.shape
# Out:
# (120, 120, 3)
